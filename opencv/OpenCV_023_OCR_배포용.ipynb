# %% [markdown]
# <img src="./lecture_image/00_title.png">

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:30px; text-align: center;"><font size=4 color=blue><b>[23차시] 학습목표</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>
# ○ OCR 방법에 대해 이해할 수 있다<br><br>
# ○ Tessaract를 이용하여 문자를 인식할 수 있다<br><br>
# ○ EasyOCR 이용한 문자를 인식할 수 있다<br><br>
# ○ 기타 OCR 라이브러리를 사용하여 문자을 인식할 수 있다
#         </font></td></tr>
# </table>

# %% [markdown]
# # OCR
#
# - 참고 : https://meissa.tistory.com/80?category=962022

# %% [markdown]
# ## 개념
#
# - OCR  =Text detection + Text recognition
#
# <img src="./lecture_image/23_ocr01.png" width=70%>
#
#   - Text detection : Object detection의 문자 찾아내기 확장 버전(Segmentation 및 문자특성 고려)
#     - 이미지 내에서 문자를 검출해낼 때엔 검출하기 위한 최소 단위를 설정
#     - 단어 단위의 탐지 : Object detection의 Regression기반의 Detection방법
#       - Anchor를 정의하고 단어의 유무, Bounding box의 크기를 추정해서 단어를 찾음
#       - (예) TextBoxes 방법
#     - 글자 단위의 방식 : 글자인 영역을 Segmentation하는 방법으로 접근
#       - (예) PixelLink 방법
#     - 두 가지 방법을 모두 활용한 방법이 있음
#       - CRAFT : Character 단위로 문자의 위치를 찾아낸 뒤 이를 연결하는 방식을 Segmentation기반으로 구현한 방법
#
#       - PMTD(Pyramid Mask Text Detector) : Mask-RCNN으로 Text영역 검출 → 단어의 사각형 배치 특성을 반영한 피라미드 형태의 Score map을 활용하여 기존의 부정확한 Mask 영역을 보완
#         - Mask-RCNN의 경우 단어 영역이 Box head에 의해 빨간색으로 잡히면 우측 처럼 boundary를 모두 Text 영역으로 잡지만, PMTD는 이를 보완하여 전체 Text 영역을 검출
#
# <img src="./lecture_image/23_ocr03.png" width=60%>
#
#   - Text recognition : 검출된 영역의 문자가 무엇인지를 인식해 내는 과정
#     - Unsegmented Data : 분리에 드는 비용이 비싸거나 어려워 Segmentation이 되어있지 않은 데이터
#       - 특징 : segment되어 있지 않은 하위데이터들끼리 시퀀스(sequence)를 이루고 있다는 점
#     - CRNN : CNN으로 문자의 특성을 검출하고 Map-To-Sequence로 변환한 후에 Bidirectional LSTM으로 문자를 인식하는 방법

# %% [markdown]
# ## Tessaract
# - 1980년대 최초로 개발된 OCR 알고리즘 중 하나
#
#
# - 다운로드 : https://github.com/UB-Mannheim/tesseract/wiki
#
#
# - tesseract-ocr-w64-setup-v5.0.0-alpha.20201127.exe 파일 다운로드 및 설치
#
# - Additional language data 체크

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Using cached pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

img = cv2.imread("./image/text.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 417.5, 466.5, -0.5)

# %%
text = pytesseract.image_to_string(img, lang="eng")
print(text)
# Out:
# Life is a journey,
# not a guided tour.
#
# - Anonymous -

# %%
img = cv2.imread("./image/nature.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 221.5, 299.5, -0.5)

# %%
text = pytesseract.image_to_string(img, lang="kor")
print(text)
# Out:
# 자연을 대출하면
# 미래는 파산합니다

# %% [markdown]
# ### 한글 이미지 인식

# %%
img = cv2.imread("./image/story.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 502.5, 412.5, -0.5)

# %%
text = pytesseract.image_to_string(img, lang="kor")
print(text)
# Out:
# 소년
#
# 여기저기서 단풍잎 같은 슬픈 가을이 뚝뚝 떨어진다. 단풍잎
# 떨어져 나온 자리마다 봄을 마련해 놓고 나못가지 위에 하늘이
# 펼쳐 있다. 가만히 하늘을 들여다보려면 눈썸에 파란 물감이
# 든다. 두 손으로 따뜻한 볼을 쓸어 보면 손바닥에도 파란 물감
# 이 묻어난다. 다시 손바닥을 들여다본다. 손금에는 맑은 강물
# 이 흐르고, 맑은 강물이 흐르고, 강물 속에는 사랑처럼 슬픈 얼
# 굴ㅡ- 아름다운 순이의 얼굴이 어린다. 소년은 황홀히 눈을
# 감아 본다. 그래도 맑은 강물은 흘러 사랑처럼 슬픈 얼굴--
# 아름다운 순이의 얼굴은 어린다.

# %% [markdown]
# ### 포스터 한글 이미지 인식

# %%
#실습

# %%
#실습
# Out:
# 자연을 대출하면
# 미래는 파산합니다

# %% [markdown]
# ### 번호판 인식

# %%
img = cv2.imread("./image/car.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 702.5, 173.5, -0.5)

# %%
text = pytesseract.image_to_string(img, lang="kor")
print(text)

# %% [markdown]
# - tesseract는 이진 이미지로 변환해서 인식을 하면 성능을 높일 수 잇다.

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
_, img_th = cv2.threshold(img, 135, 255, cv2.THRESH_BINARY)

text = pytesseract.image_to_string(img_th, lang="kor")
print(text)
# Out:
# | 52 5108 |

# %% [markdown]
# ## EasyOCR
# - 문자영역 인식, 문자 인식을 쉽게 할 수 있게 하는 파이썬 라이브러리
# - 간단하고 직관적
# - 80개 이상의 언어를 지원
# - 문자 추출은 CRAFT를 문자 인식은 CRNN을 사용
#
#
# - 수행 결과로 텍스트의 바운딩 박스 좌표와 읽은 문자를 반환
#
#
# - 참고 : https://github.com/JaidedAI/EasyOCR

# %%
#!pip uninstall opencv-python
# !pip install opencv-python==4.5.4.60 easyocr
# Out:
# Requirement already satisfied: opencv-python==4.5.4.60 in c:\users\ai\appdata\roaming\python\python37\site-packages (4.5.4.60)
# Requirement already satisfied: easyocr in c:\users\ai\appdata\roaming\python\python37\site-packages (1.6.2)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from opencv-python==4.5.4.60) (1.21.5)
# Requirement already satisfied: PyYAML in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: Pillow in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from easyocr) (9.2.0)
# Requirement already satisfied: torch in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from easyocr) (1.12.1)
# Requirement already satisfied: scikit-image in c:\users\ai\appdata\roaming\python\python37\site-packages (from easyocr) (0.19.3)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in c:\users\ai\appdata\roaming\python\python37\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: scipy in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from easyocr) (1.7.3)
# Requirement already satisfied: Shapely in c:\users\ai\appdata\roaming\python\python37\site-packages (from easyocr) (1.8.4)
# Requirement already satisfied: ninja in c:\users\ai\appdata\roaming\python\python37\site-packages (from easyocr) (1.10.2.3)
# Requirement already satisfied: pyclipper in c:\users\ai\appdata\roaming\python\python37\site-packages (from easyocr) (1.3.0.post3)
# Requirement already satisfied: torchvision>=0.5 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from easyocr) (0.13.1)
# Requirement already satisfied: python-bidi in c:\users\ai\appdata\roaming\python\python37\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: requests in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: six in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\ai\appdata\roaming\python\python37\site-packages (from scikit-image->easyocr) (2.6.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\ai\appdata\roaming\python\python37\site-packages (from scikit-image->easyocr) (2021.11.2)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from scikit-image->easyocr) (2.21.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\ai\appdata\roaming\python\python37\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ai\anaconda3\envs\opencv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)

# %%
img = cv2.imread("./image/story.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 502.5, 412.5, -0.5)

# %%
import easyocr

reader = easyocr.Reader(["ko", "en"])
result = reader.readtext(img)
result
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11764\3733838888.py in <module>
# ----> 1 import easyocr
#       2
#       3 reader = easyocr.Reader(["ko", "en"])
#       4 result = reader.readtext(img)
#       5 result
#
# ~\AppData\Roaming\Python\Python37\site-packages\easyocr\__init__.py in <module>
# ----> 1 from .easyocr import Reader
#       2
#       3 __version__ = '1.6.2'
#
# ~\AppData\Roaming\Python\Python37\site-packages\easyocr\easyocr.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .recognition import get_recognizer, get_text
#       4 from .utils import group_text_box, get_image_list, calculate_md5, get_paragraph,\
#       5                    download_and_unzip, printProgressBar, diff, reformat_input,\
#
# ~\AppData\Roaming\Python\Python37\site-packages\easyocr\recognition.py in <module>
#       1 from PIL import Image
# ----> 2 import torch
#       3 import torch.backends.cudnn as cudnn
#       4 import torch.utils.data
#       5 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.10.0-cp37-cp37m-win_amd64.whl (455.9 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ai\appdata\roaming\python\python37\site-packages (from tensorflow) (3.3.0)
# Collecting keras<2.11,>=2.10.0
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from tensorflow) (21.3)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting tensorboard<2.11,>=2.10
#   Using cached tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.5-cp37-cp37m-win_amd64.whl (896 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.49.1-cp37-cp37m-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 10.4 MB/s eta 0:00:00
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.7.0-cp37-cp37m-win_amd64.whl (2.6 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.27.0-cp37-cp37m-win_amd64.whl (1.5 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.14.1-cp37-cp37m-win_amd64.whl (35 kB)
# Requirement already satisfied: setuptools in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from tensorflow) (63.4.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from tensorflow) (1.21.6)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.11.1-py2.py3-none-any.whl (167 kB)
#      ---------------------------------------- 167.1/167.1 kB ? eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from packaging->tensorflow) (3.0.9)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.11.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ai\anaconda3\envs\paddleocr\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.8.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.1-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, oauthlib, keras-preprocessing, h5py, grpcio, google-pasta, gast, astunparse, absl-py, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'c:\\users\\ai\\appdata\\roaming\\python\\python37\\site-packages\\google\\~rotobuf\\internal\\_api_implementation.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %% [markdown]
# ## PaddleOCR
#
# - 참고
#   - https://learnopencv.com/optical-character-recognition-using-paddleocr/?ck_subscriber_id=1390420859
#   - https://github.com/PaddlePaddle/PaddleOCR
#
#
# - 텍스트 감지, 텍스트 방향 분류기 및 텍스트 인식을 제공
# - PP-OCR 및 SRN, NRTR 등과 같은 최신 알고리즘을 포함하여 툴킷에 다양한 모델을 제공
# - 80 개 이상의 언어를 지원
#
#
# <img src="./lecture_image/23_paddleocr1.png" width=80%>

# %% [markdown]
# - 설치

# %%
# !conda create paddleocr python==3.7
# Out:
# 'conda'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !activate paddleocr
# Out:
# 'activate'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# !git clone https://gitee.com/paddlepaddle/PaddleOCR.git
# Out:
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
# !pip install -r ./PaddleOCR/requirements.txt
# Out:
# Requirement already satisfied: shapely in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 1)) (1.8.4)
# Requirement already satisfied: scikit-image in c:\users\ai\anaconda3\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: imgaug in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 4)) (1.3.0.post3)
# Requirement already satisfied: lmdb in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: tqdm in c:\users\ai\anaconda3\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 6)) (4.64.0)
# Requirement already satisfied: numpy in c:\users\ai\anaconda3\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 7)) (1.21.5)
# Requirement already satisfied: visualdl in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: rapidfuzz in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 9)) (2.10.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\ai\anaconda3\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 10)) (3.4.11.45)
# Requirement already satisfied: cython in c:\users\ai\anaconda3\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 11)) (0.29.28)
# Requirement already satisfied: lxml in c:\users\ai\anaconda3\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: premailer in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 13)) (3.10.0)
# Requirement already satisfied: openpyxl in c:\users\ai\anaconda3\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 14)) (3.0.9)
# Requirement already satisfied: attrdict in c:\users\ai\appdata\roaming\python\python39\site-packages (from -r ./PaddleOCR/requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (1.7.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (2.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (21.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (9.0.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (2021.7.2)
# Requirement already satisfied: opencv-python in c:\users\ai\anaconda3\lib\site-packages (from imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (3.4.11.45)
# Requirement already satisfied: six in c:\users\ai\anaconda3\lib\site-packages (from imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\ai\anaconda3\lib\site-packages (from imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (3.5.1)
# Requirement already satisfied: colorama in c:\users\ai\anaconda3\lib\site-packages (from tqdm->-r ./PaddleOCR/requirements.txt (line 6)) (0.4.4)
# Requirement already satisfied: requests in c:\users\ai\appdata\roaming\python\python39\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.28.1)
# Requirement already satisfied: pandas in c:\users\ai\anaconda3\lib\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: bce-python-sdk in c:\users\ai\appdata\roaming\python\python39\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (0.8.74)
# Requirement already satisfied: flask>=1.1.1 in c:\users\ai\anaconda3\lib\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: multiprocess in c:\users\ai\appdata\roaming\python\python39\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (0.70.13)
# Requirement already satisfied: Flask-Babel>=1.0.0 in c:\users\ai\appdata\roaming\python\python39\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: protobuf>=3.11.0 in c:\users\ai\anaconda3\lib\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (3.18.1)
# Requirement already satisfied: jarowinkler<2.0.0,>=1.2.0 in c:\users\ai\appdata\roaming\python\python39\site-packages (from rapidfuzz->-r ./PaddleOCR/requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: cachetools in c:\users\ai\anaconda3\lib\site-packages (from premailer->-r ./PaddleOCR/requirements.txt (line 13)) (4.2.2)
# Requirement already satisfied: cssselect in c:\users\ai\anaconda3\lib\site-packages (from premailer->-r ./PaddleOCR/requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: cssutils in c:\users\ai\appdata\roaming\python\python39\site-packages (from premailer->-r ./PaddleOCR/requirements.txt (line 13)) (2.6.0)
# Requirement already satisfied: et-xmlfile in c:\users\ai\anaconda3\lib\site-packages (from openpyxl->-r ./PaddleOCR/requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: pytz in c:\users\ai\anaconda3\lib\site-packages (from Flask-Babel>=1.0.0->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2021.3)
# Requirement already satisfied: Babel>=2.3 in c:\users\ai\anaconda3\lib\site-packages (from Flask-Babel>=1.0.0->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.9.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ai\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ai\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: future>=0.6.0 in c:\users\ai\anaconda3\lib\site-packages (from bce-python-sdk->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (0.18.2)
# Requirement already satisfied: pycryptodome>=3.8.0 in c:\users\ai\appdata\roaming\python\python39\site-packages (from bce-python-sdk->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (3.15.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: dill>=0.3.5.1 in c:\users\ai\anaconda3\lib\site-packages (from multiprocess->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (0.3.5.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ai\anaconda3\lib\site-packages (from requests->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ai\anaconda3\lib\site-packages (from requests->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ai\anaconda3\lib\site-packages (from requests->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ai\anaconda3\lib\site-packages (from requests->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.6)

# %%
# !pip install paddlepaddle-gpu paddleocr --user
# !pip install paddlepaddle paddleocr --user
# Out:
# Collecting paddlepaddle
#   WARNING: The scripts csscapture.exe, csscombine.exe and cssparse.exe are installed in 'C:\Users\AI\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script visualdl.exe is installed in 'C:\Users\AI\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fleetrun.exe is installed in 'C:\Users\AI\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script paddleocr.exe is installed in 'C:\Users\AI\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Downloading paddlepaddle-2.3.2-cp39-cp39-win_amd64.whl (64.3 MB)
# Collecting paddleocr
#   Using cached paddleocr-2.6.0.1-py3-none-any.whl (389 kB)
# Collecting paddle-bfloat==0.1.7
#   Downloading paddle_bfloat-0.1.7-cp39-cp39-win_amd64.whl (39 kB)
# Requirement already satisfied: Pillow in c:\users\ai\anaconda3\lib\site-packages (from paddlepaddle) (9.0.1)
# Requirement already satisfied: decorator in c:\users\ai\anaconda3\lib\site-packages (from paddlepaddle) (5.1.1)
# Requirement already satisfied: numpy>=1.13 in c:\users\ai\anaconda3\lib\site-packages (from paddlepaddle) (1.21.5)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\ai\anaconda3\lib\site-packages (from paddlepaddle) (3.3.0)
# Collecting astor
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: protobuf<=3.20.0,>=3.1.0 in c:\users\ai\anaconda3\lib\site-packages (from paddlepaddle) (3.18.1)
# Requirement already satisfied: six in c:\users\ai\anaconda3\lib\site-packages (from paddlepaddle) (1.16.0)
# Requirement already satisfied: requests>=2.20.0 in c:\users\ai\appdata\roaming\python\python39\site-packages (from paddlepaddle) (2.28.1)
# Collecting visualdl
#   Using cached visualdl-2.4.1-py3-none-any.whl (4.9 MB)
# Collecting imgaug
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Collecting shapely
#   Downloading Shapely-1.8.4-cp39-cp39-win_amd64.whl (1.3 MB)
# Collecting premailer
#   Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Collecting lmdb
#   Downloading lmdb-1.3.0-cp39-cp39-win_amd64.whl (106 kB)
# Collecting attrdict
#   Using cached attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: opencv-contrib-python in c:\users\ai\anaconda3\lib\site-packages (from paddleocr) (3.4.11.45)
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post3-cp39-cp39-win_amd64.whl (94 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.10.0-cp39-cp39-win_amd64.whl (917 kB)
# Requirement already satisfied: opencv-python in c:\users\ai\anaconda3\lib\site-packages (from paddleocr) (3.4.11.45)
# Requirement already satisfied: lxml in c:\users\ai\anaconda3\lib\site-packages (from paddleocr) (4.8.0)
# Requirement already satisfied: tqdm in c:\users\ai\anaconda3\lib\site-packages (from paddleocr) (4.64.0)
# Requirement already satisfied: scikit-image in c:\users\ai\anaconda3\lib\site-packages (from paddleocr) (0.19.2)
# Requirement already satisfied: cython in c:\users\ai\anaconda3\lib\site-packages (from paddleocr) (0.29.28)
# Requirement already satisfied: openpyxl in c:\users\ai\anaconda3\lib\site-packages (from paddleocr) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.20.0->paddlepaddle) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2021.10.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2.6)
# Requirement already satisfied: imageio in c:\users\ai\anaconda3\lib\site-packages (from imgaug->paddleocr) (2.9.0)
# Requirement already satisfied: scipy in c:\users\ai\anaconda3\lib\site-packages (from imgaug->paddleocr) (1.7.3)
# Requirement already satisfied: matplotlib in c:\users\ai\anaconda3\lib\site-packages (from imgaug->paddleocr) (3.5.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->paddleocr) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->paddleocr) (2021.7.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->paddleocr) (2.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ai\anaconda3\lib\site-packages (from scikit-image->paddleocr) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ai\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->paddleocr) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->imgaug->paddleocr) (4.25.0)
# Requirement already satisfied: et-xmlfile in c:\users\ai\anaconda3\lib\site-packages (from openpyxl->paddleocr) (1.1.0)
# Requirement already satisfied: cssselect in c:\users\ai\anaconda3\lib\site-packages (from premailer->paddleocr) (1.1.0)
# Collecting cssutils
#   Using cached cssutils-2.6.0-py3-none-any.whl (399 kB)
# Requirement already satisfied: cachetools in c:\users\ai\anaconda3\lib\site-packages (from premailer->paddleocr) (4.2.2)
# Collecting jarowinkler<2.0.0,>=1.2.0
#   Downloading jarowinkler-1.2.1-cp39-cp39-win_amd64.whl (61 kB)
# Requirement already satisfied: colorama in c:\users\ai\anaconda3\lib\site-packages (from tqdm->paddleocr) (0.4.4)
# Collecting bce-python-sdk
#   Using cached bce_python_sdk-0.8.74-py3-none-any.whl (204 kB)
# Requirement already satisfied: pandas in c:\users\ai\anaconda3\lib\site-packages (from visualdl->paddleocr) (1.4.2)
# Collecting Flask-Babel>=1.0.0
#   Using cached Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: flask>=1.1.1 in c:\users\ai\anaconda3\lib\site-packages (from visualdl->paddleocr) (1.1.2)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py39-none-any.whl (132 kB)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ai\anaconda3\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.0.1)
# Requirement already satisfied: pytz in c:\users\ai\anaconda3\lib\site-packages (from Flask-Babel>=1.0.0->visualdl->paddleocr) (2021.3)
# Requirement already satisfied: Babel>=2.3 in c:\users\ai\anaconda3\lib\site-packages (from Flask-Babel>=1.0.0->visualdl->paddleocr) (2.9.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ai\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask>=1.1.1->visualdl->paddleocr) (2.0.1)
# Requirement already satisfied: future>=0.6.0 in c:\users\ai\anaconda3\lib\site-packages (from bce-python-sdk->visualdl->paddleocr) (0.18.2)
# Collecting pycryptodome>=3.8.0
#   Using cached pycryptodome-3.15.0-cp35-abi3-win_amd64.whl (1.9 MB)
# Requirement already satisfied: dill>=0.3.5.1 in c:\users\ai\anaconda3\lib\site-packages (from multiprocess->visualdl->paddleocr) (0.3.5.1)
# Installing collected packages: pycryptodome, shapely, multiprocess, jarowinkler, Flask-Babel, cssutils, bce-python-sdk, visualdl, rapidfuzz, pyclipper, premailer, paddle-bfloat, lmdb, imgaug, attrdict, astor, paddlepaddle, paddleocr
# Successfully installed Flask-Babel-2.0.0 astor-0.8.1 attrdict-2.0.1 bce-python-sdk-0.8.74 cssutils-2.6.0 imgaug-0.4.0 jarowinkler-1.2.1 lmdb-1.3.0 multiprocess-0.70.13 paddle-bfloat-0.1.7 paddleocr-2.6.0.1 paddlepaddle-2.3.2 premailer-3.10.0 pyclipper-1.3.0.post3 pycryptodome-3.15.0 rapidfuzz-2.10.0 shapely-1.8.4 visualdl-2.4.1

# %% [markdown]
# - 라이브러리 및 학습된 모델 로딩

# %%
from paddleocr import PaddleOCR, draw_ocr
import os
import cv2
import matplotlib.pyplot as plt

ocr = PaddleOCR(use_angle_cls=True, lang="en")
# Out:
# [2022/09/23 15:20:57] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\AI/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_fce_box_type='poly', det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\AI/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_box_type='quad', det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_polygon=False, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv3', output='./output', precision='fp32', process_id=0, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='C:\\Users\\AI\\AppData\\Roaming\\Python\\Python37\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\AI/.paddleocr/whl\\rec\\en\\en_PP-OCRv3_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', save_pdf=False, scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, shape_info_filename=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-Structurev2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gpu=False, use_mp=False, use_onnx=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)

# %% [markdown]
# - 인식

# %%
def result_ocr(img_path, result, font) :
    image = cv2.imread(img_path)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    
    print(result)
    
    boxes = [line[0] for line in result]
    txts = [line[1][0] for line in result]
    conf = [line[1][1] for line in result]
    
    im_show = draw_ocr(image, boxes, txts, conf, font_path=font)
    
    plt.figure(figsize=(12,12))
    plt.imshow(im_show)
    plt.axis("off")

# %% [markdown]
# - 영수증 인식

# %%
img_path = "./image/curved_text1.png"

result = ocr.ocr(img_path)

font = "./image/HMFMPYUN.TTF"

result_ocr(img_path, result, font)
# Out:
# [2022/09/23 16:00:28] ppocr DEBUG: dt_boxes num : 2, elapse : 0.5717728137969971
# [2022/09/23 16:00:28] ppocr DEBUG: cls num  : 2, elapse : 0.028970956802368164
# [2022/09/23 16:00:29] ppocr DEBUG: rec_res num  : 2, elapse : 0.25352978706359863
# [[[[339.0, 410.0], [461.0, 417.0], [456.0, 515.0], [334.0, 508.0]], ('TE', 0.5127403736114502)], [[[150.0, 503.0], [655.0, 480.0], [662.0, 624.0], [156.0, 647.0]], ('BEACH', 0.995928943157196)]]

# %% [markdown]
# - ID 카드 인식

# %% [markdown]
# - 손글씨 인식

# %%
#실습
# Out:
# [2022/09/12 16:43:55] ppocr DEBUG: dt_boxes num : 5, elapse : 0.555182933807373
# [2022/09/12 16:43:55] ppocr DEBUG: cls num  : 5, elapse : 0.048870086669921875
# [2022/09/12 16:43:55] ppocr DEBUG: rec_res num  : 5, elapse : 0.4703562259674072

# %% [markdown]
# - 자동차 번호판

# %%
#실습
# Out:
# [2022/09/12 16:45:32] ppocr DEBUG: dt_boxes num : 1, elapse : 0.1376328468322754
# [2022/09/12 16:45:32] ppocr DEBUG: cls num  : 1, elapse : 0.010944366455078125
# [2022/09/12 16:45:32] ppocr DEBUG: rec_res num  : 1, elapse : 0.0917809009552002

# %% [markdown]
# - 도로 표지판

# %%
#실습
# Out:
# [2022/09/12 16:46:56] ppocr DEBUG: dt_boxes num : 8, elapse : 0.39295053482055664
# [2022/09/12 16:46:56] ppocr DEBUG: cls num  : 8, elapse : 0.07878589630126953
# [2022/09/12 16:46:56] ppocr DEBUG: rec_res num  : 8, elapse : 0.733616828918457

# %% [markdown]
# - 곡선 텍스트

# %%
#실습
# Out:
# [2022/09/12 16:50:28] ppocr DEBUG: dt_boxes num : 2, elapse : 0.39397287368774414
# [2022/09/12 16:50:28] ppocr DEBUG: cls num  : 2, elapse : 0.020034313201904297
# [2022/09/12 16:50:28] ppocr DEBUG: rec_res num  : 2, elapse : 0.18062329292297363

# %% [markdown]
# ## 구글 OCR API 활용
#
# - 참고 : https://cloud.google.com/vision/docs/quickstart

# %% [markdown]
# ## Naver 클로버 OCR
#
# - 참고 : https://clova.ai/ocr?lang=ko

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:40px; text-align: center;"><font size=4 color=blue><b>[23차시] 정리하기</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>○
#         </font></td></tr>
# </table>
